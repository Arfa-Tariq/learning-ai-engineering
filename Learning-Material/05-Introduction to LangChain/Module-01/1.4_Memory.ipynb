# %% [markdown]
# <a href="https://colab.research.google.com/github/Arfa-Tariq/learning-ai-engineering/blob/main/Learning-Material/05-Introduction%20to%20LangChain/Module-01/1.4_Memory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone the repo
! git clone --depth 1 https://github.com/langchain-ai/lca-lc-foundations.git
# Out:
# Cloning into 'lca-lc-foundations'...
# remote: Enumerating objects: 140, done.
# remote: Counting objects: 100% (140/140), done.
# remote: Compressing objects: 100% (121/121), done.
# remote: Total 140 (delta 27), reused 85 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (140/140), 1.09 MiB | 4.69 MiB/s, done.
# Resolving deltas: 100% (27/27), done.

# %%
# !pip install -q langchain_groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 2.5 MB/s eta 0:00:00

# %%
from google.colab import userdata
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain_groq import ChatGroq
from pprint import pprint
from langgraph.checkpoint.memory import InMemorySaver

# %%
llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key=userdata.get('groq_key'),
    temperature=0,
)

# %%
agent= create_agent(model=llm,
                    checkpointer=InMemorySaver(),)

# %%
question = HumanMessage(content= "Hello my name is Savvy and my fav colour is blue.")
config = {"configurable":{"thread_id":"1"}}

# %%
response= agent.invoke({"messages":[question]},
                       config)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Savvy and my fav colour is blue.', additional_kwargs={}, response_metadata={}, id='d844e573-26f8-426e-a602-2b2a802c9284'),
# ...

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Savvy and my fav colour is blue.', additional_kwargs={}, response_metadata={}, id='d844e573-26f8-426e-a602-2b2a802c9284'),
# ...
