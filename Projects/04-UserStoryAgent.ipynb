# %% [markdown]
# <a href="https://colab.research.google.com/github/Arfa-Tariq/learning-ai-engineering/blob/main/Projects/04-UserStoryAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 💻 Build
#
# Requirement
#
# ↓
#
# Generate
#
# User Story
# Acceptance Criteria
# Priority
#
# Return JSON.

# %% [markdown]
# As a [type of user]I want to [some goal]So that [some reason or value]

# %% [markdown]
# 1. The Input (Your Raw Requirement)"We need a way for users to reset their passwords because they keep locking themselves out, which is overwhelming our support team."
#
# 2. The Output (The Generated Assets)User StoryAs a registered user who forgot my password,I want to securely request a password reset link via email,So that I can regain access to my account without contacting customer support.Acceptance CriteriaScenario 1: Requesting a reset link.Given the user is on the login page,When they click "Forgot Password" and enter a registered email,Then the system sends a password reset token valid for 24 hours.Scenario 2: Invalid email entry.Given the user enters an email not found in the database,Then the system displays a generic error message to protect user privacy.
#
# Priority RatingPriority: HighJustification: Directly reduces operational support costs and improves user retention.

# %%
import os
from google.colab import userdata
from langchain_core import ChatGroq

# %%
os.environ["GROQ_API_KEY"] = userdata.get('groq_key')

# %%
llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key=os.environ["GROQ_API_KEY"],
    temperature=0.1,
)
