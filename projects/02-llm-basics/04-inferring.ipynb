# %% [markdown]
# <a href="https://colab.research.google.com/github/Arfa-Tariq/learning-ai-engineering/blob/main/projects/02-llm-basics/04-inferring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Inferring
# In this notebook, we will infer sentiment and topics from product reviews and news articles.

# %%
# !pip install -q groq

from groq import Groq
from google.colab import userdata

GROQ_API_KEY = userdata.get('groq_key')
client = Groq(api_key=GROQ_API_KEY)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 2.9 MB/s eta 0:00:00

# %%
def get_completion(prompt, model="llama-3.3-70b-versatile"):
  messages = [{"role": "user", "content": prompt}]
  response = client.chat.completions.create(
    model=model,
    messages=messages,
    temperature=1,)
  return response.choices[0].message.content

# %% [markdown]
# ## Product review text

# %%
lamp_review = """
Needed a nice lamp for my bedroom, and this one had \
additional storage and not too high of a price point. \
Got it fast.  The string to our lamp broke during the \
transit and the company happily sent over a new one. \
Came within a few days as well. It was easy to put \
together.  I had a missing part, so I contacted their \
support and they very quickly got me the missing piece! \
Lumina seems to me to be a great company that cares \
about their customers and products!!
"""

# %% [markdown]
# ## Sentiment (positive/negative)

# %%
prompt = f"""
What is the sentiment of the following product review,
which is delimited with triple backticks?

Review text: '''{lamp_review}'''
"""
response = get_completion(prompt)
print(response)
# Out:
# The sentiment of the review is overwhelmingly positive. The customer is satisfied with the product, its features, and the price. They also had a good experience with the company's customer support, who responded promptly to issues with the product (a broken string and a missing part). The use of phrases such as "Lumina seems to me to be a great company" and "cares about their customers and products" further emphasize the customer's positive sentiment towards the company. Overall, the review expresses a high level of satisfaction and trust in the company and its products.

# %% [markdown]
# ## Identify types of emotions

# %%
prompt = f"""
Identify a list of emotions that the writer of the \
following review is expressing. Include no more than \
five items in the list. Format your answer as a list of \
lower-case words separated by commas.

Review text: '''{lamp_review}'''
"""
response = get_completion(prompt)
print(response)
# Out:
# satisfaction, happiness, appreciation, relief, gratitude

# %% [markdown]
# ## Identify anger

# %%
prompt = f"""
Is the writer of the following review expressing anger?\
The review is delimited with triple backticks. \
Give your answer as either yes or no.

Review text: '''{lamp_review}'''
"""
response = get_completion(prompt)
print(response)
# Out:
# no

# %%
prompt = f"""
Is the writer of the following review expressing satisfaction with customer support?\
The review is delimited with triple backticks. \
Give your answer as either yes or no.

Review text: '''{lamp_review}'''
"""
response = get_completion(prompt)
print(response)
# Out:
# Yes.

# %% [markdown]
# ## Extract product and company name from customer reviews

# %%
prompt = f"""
Identify the following items from the review text:
- Item purchased by reviewer
- Company that made the item

The review is provided delimited with triple backticks. \
Format your response as a JSON object with \
"Item" and "Brand" as the keys.
If the information isn't present, use "unknown" \
as the value.
Make your response as short as possible.

Review text: '''{lamp_review}'''
"""
response = get_completion(prompt)
print(response)
# Out:
# ```json
# {
#   "Item": "lamp",
#   "Brand": "Lumina"
# }
# ```

# %% [markdown]
# ## Doing multiple tasks at once

# %%
prompt = f"""
Identify the following items from the review text:
- Sentiment (positive or negative)
- Is the reviewer expressing anger? (true or false)
- Item purchased by reviewer
- Company that made the item

The review is delimited with triple backticks. \
Format your response as a JSON object with \
"Sentiment", "Anger", "Item" and "Brand" as the keys.
If the information isn't present, use "unknown" \
as the value.
Make your response as short as possible.
Format the Anger value as a boolean.

Review text: '''{lamp_review}'''
"""
response = get_completion(prompt)
print(response)
# Out:
# ```json
# {
#   "Sentiment": "positive",
#   "Anger": false,
#   "Item": "lamp",
#   "Brand": "Lumina"
# }
# ```

# %% [markdown]
# ## Inferring topics

# %%
story = """
In a recent survey conducted by the government,
public sector employees were asked to rate their level
of satisfaction with the department they work at.
The results revealed that NASA was the most popular
department with a satisfaction rating of 95%.

One NASA employee, John Smith, commented on the findings,
stating, "I'm not surprised that NASA came out on top.
It's a great place to work with amazing people and
incredible opportunities. I'm proud to be a part of
such an innovative organization."

The results were also welcomed by NASA's management team,
with Director Tom Johnson stating, "We are thrilled to
hear that our employees are satisfied with their work at NASA.
We have a talented and dedicated team who work tirelessly
to achieve our goals, and it's fantastic to see that their
hard work is paying off."

The survey also revealed that the
Social Security Administration had the lowest satisfaction
rating, with only 45% of employees indicating they were
satisfied with their job. The government has pledged to
address the concerns raised by employees in the survey and
work towards improving job satisfaction across all departments.
"""

# %% [markdown]
# ## Infer 5 topics

# %%
prompt = f"""
Determine five topics that are being discussed in the \
following text, which is delimited by triple backticks.

Make each item either one or two words long.

Format your response as a list of items separated by commas.

Text sample: '''{story}'''
"""
response = get_completion(prompt)
print(response)
# Out:
# NASA, Government, Survey, Employees, Satisfaction

# %%
response.split(sep=',')
# Out:
# ['NASA', ' Government', ' Survey', ' Employees', ' Satisfaction']

# %% [markdown]
# ## Sample Excercise 2

# %%
review = """
I recently bought the SmartHome Security Camera from TechGadgets Inc.
The installation was super easy – took me less than 5 minutes.
The video quality is amazing, even at night.
The mobile app works well, but sometimes it takes a few seconds to load.
I love the motion detection alerts, but I wish the battery lasted longer.
Overall, I'm very satisfied with the product and would recommend it to friends.
The price is a bit high, but I think it's worth it for the quality.
"""

# For sentiment analysis
tweet = "I absolutely love this new update! The interface is beautiful and so intuitive. 🚀"

# For emotion detection
text = "I can't believe I got the job! After months of applying, I finally made it. I'm so excited but also nervous."

# For category detection
news = """
Apple Inc. announced today that it will be opening a new research facility in
Austin, Texas, focused on artificial intelligence and machine learning.
The facility is expected to create 500 new jobs by 2025.
"""

# For entity extraction
email = """
From: john.doe@email.com
To: support@company.com
Subject: Order #12345 Issue

Hi, I ordered a pair of headphones last week (Order #12345) and they arrived
damaged. The box was crushed and the left earphone doesn't work.
Please help me with a replacement or refund.
Thanks,
John Doe
"""

# %%
prompt = f"""
What is the sentiment of the following product review,
which is delimited with triple backticks?

Review text: '''{review}'''
"""
response = get_completion(prompt)
print(response)
# Out:
# The sentiment of this product review is generally positive. The reviewer mentions several strengths of the product, such as:
#
# * Easy installation
# * Amazing video quality
# * Useful motion detection alerts
# * Good mobile app functionality
#
# They also mention a few weaknesses, such as:
#
# * Mobile app loading time
# * Battery life
# * High price
#
# However, the reviewer states that they are "very satisfied" with the product and would recommend it to friends, indicating that the strengths outweigh the weaknesses. They also mention that the price is "worth it" for the quality, which suggests that they are willing to pay a premium for a good product. Overall, the review has a positive tone and suggests that the product is a good choice for those in the market for a security camera.

# %%
prompt = f"""
Identify a list of emotions that the writer of the \
following review is expressing. Include no more than \
five items in the list. Format your answer as a list of \
lower-case words separated by commas.

Review text: '''{review}'''
"""
response = get_completion(prompt)
print(response)
# Out:
# satisfaction, love, frustration, happiness, contentment

# %%
prompt= f"""
What is the sentiment of the following user tweet, which is provided
delimeted by triple backticks.

Tweet: ```{tweet}```
"""
response = get_completion(prompt)
print(response)
# Out:
# The sentiment of the tweet is overwhelmingly positive. The user expresses their love for the new update, praises the interface as "beautiful" and "intuitive", and includes a rocket ship emoji (🚀) which often symbolizes excitement and enthusiasm. Overall, the tone is enthusiastic and appreciative.

# %%
prompt = f"""
Determine five topics that are being discussed in the \
following news, which is delimited by triple backticks.

Make each item either one or two words long.

Format your response as a list of items separated by commas.

Text sample: '''{news}'''
"""
response = get_completion(prompt)
print(response)
# Out:
# Apple, Texas, Facility, Jobs, Research

# %%
topic_list = [
    "Apple", "local government", "engineering",
    "employee satisfaction", "federal government",
    "Texas",
]

# %%
prompt = f"""
Determine whether each item in the following list of \
topics is a topic in the text below, which
is delimited with triple backticks.

Give your answer as follows:
item from the list: 0 or 1

List of topics: {", ".join(topic_list)}

Text sample: '''{news}'''
"""
response = get_completion(prompt)
print(response)
# Out:
# Here are the results:
#
# Apple: 1
# local government: 0
# engineering: 0
# employee satisfaction: 0
# federal government: 0
# Texas: 1

# %% [markdown]
# ## Make a news alert for certain topics

# %%
topic_dict = {i.split(': ')[0]: int(i.split(': ')[1]) for i in response.split(sep='\n') if ': ' in i}
if topic_dict['Apple'] == 1:
    print("ALERT: New ALert! Check out this news from Apple")
# Out:
# ALERT: New ALert! Check out this news from Apple
