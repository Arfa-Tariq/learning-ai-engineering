# %% [markdown]
# <a href="https://colab.research.google.com/github/Arfa-Tariq/learning-ai-engineering/blob/main/projects/02-llm-basics/02_iterative_prompt_dev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Iterative Prompt Development
# In this notebook, we'll iteratively analyze and refine your prompts to generate marketing copy from a product fact sheet.

# %%
# !pip install -q groq

from groq import Groq
from google.colab import userdata

GROQ_API_KEY = userdata.get('groq_key')
client = Groq(api_key=GROQ_API_KEY)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 5.4 MB/s eta 0:00:00

# %%
def get_completion(prompt, model="llama-3.3-70b-versatile"):
  messages = [{"role": "user", "content": prompt}]
  response = client.chat.completions.create(
    model=model,
    messages=messages,
    temperature=1,)
  return response.choices[0].message.content

# %% [markdown]
# ## Generate a marketing product description from a product fact sheet

# %%
fact_sheet_chair = """
OVERVIEW
- Part of a beautiful family of mid-century inspired office furniture,
including filing cabinets, desks, bookcases, meeting tables, and more.
- Several options of shell color and base finishes.
- Available with plastic back and front upholstery (SWC-100)
or full upholstery (SWC-110) in 10 fabric and 6 leather options.
- Base finish options are: stainless steel, matte black,
gloss white, or chrome.
- Chair is available with or without armrests.
- Suitable for home or business settings.
- Qualified for contract use.

CONSTRUCTION
- 5-wheel plastic coated aluminum base.
- Pneumatic chair adjust for easy raise/lower action.

DIMENSIONS
- WIDTH 53 CM | 20.87”
- DEPTH 51 CM | 20.08”
- HEIGHT 80 CM | 31.50”
- SEAT HEIGHT 44 CM | 17.32”
- SEAT DEPTH 41 CM | 16.14”

OPTIONS
- Soft or hard-floor caster options.
- Two choices of seat foam densities:
 medium (1.8 lb/ft3) or high (2.8 lb/ft3)
- Armless or 8 position PU armrests

MATERIALS
SHELL BASE GLIDER
- Cast Aluminum with modified nylon PA6/PA66 coating.
- Shell thickness: 10 mm.
SEAT
- HD36 foam

COUNTRY OF ORIGIN
- Italy
"""

# %%
prompt = f"""
Your task is to help a marketing team create a
description for a retail website of a product based
on a technical fact sheet.

Write a product description based on the information
provided in the technical specifications delimited by
triple backticks.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# **Mid-Century Inspired Office Chair**
#
# Elevate your home or business workspace with our stylish and versatile mid-century inspired office chair. Part of a larger family of coordinating furniture pieces, including filing cabinets, desks, bookcases, and meeting tables, this chair is designed to bring a touch of elegance and sophistication to any setting.
#
# With a range of shell color and base finish options to choose from, including stainless steel, matte black, gloss white, and chrome, you can customize your chair to perfectly complement your unique decor. Plus, with 10 fabric and 6 leather upholstery options available, you're sure to find the perfect match for your style.
#
# Our chair features a durable 5-wheel plastic coated aluminum base and pneumatic adjust system, making it easy to raise or lower the seat to your desired height. The chair is also available with or without armrests, and with two different seat foam densities to ensure optimal comfort and support.
#
# ...

# %% [markdown]
# ## Issue 1: The text is too long
# - Limit the number of words/sentences/characters.

# %%
prompt = f"""
Your task is to help a marketing team create a
description for a retail website of a product based
on a technical fact sheet.

Write a product description based on the information
provided in the technical specifications delimited by
triple backticks.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Mid-century inspired office chair with customizable shell, base, and upholstery options.

# %%
len(response.split(" "))
# Out:
# 11

# %% [markdown]
# ## Issue 2. The text is too short now
# - Adjust the prompting style

# %%
prompt = f"""
Your task is to help a marketing team create a
description for a retail website of a product based
on a technical fact sheet.

Write a product description based on the information
provided in the technical specifications delimited by
triple backticks.

This description is intended for furniture retailers, so
should be technical in nature and focus on the materials
the product is constructed from.

Don't be too concissive and atleast 3 sentences without exceeding 50 word limit.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# The chair features a cast aluminum base with a modified nylon PA6/PA66 coating and a 10mm thick shell. It has a 5-wheel plastic coated aluminum base and a pneumatic chair adjust. The seat is made of HD36 foam.

# %%
len(response.split(" "))
# Out:
# 38

# %% [markdown]
# ## Issue 3. Description needs a table of dimensions
# - Ask it to extract information and organize it in a table.

# %%
prompt = f"""
Your task is to help a marketing team create a
description for a retail website of a product based
on a technical fact sheet.

Write a product description based on the information
provided in the technical specifications delimited by
triple backticks.

The description is intended for furniture retailers,
so should be technical in nature and focus on the
materials the product is constructed from.

At the end of the description, include every 7-character
Product ID in the technical specification.

After the description, include a table that gives the
product's dimensions. The table should have two columns.
In the first column include the name of the dimension.
In the second column include the measurements in inches only.

Give the table the title 'Product Dimensions'.

Format every information as proper HTML sections with headings for a website.
Divide the description into different sections. Place the description in a <div> element.

Technical specifications: ```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)
# Out:
# <h1>Product Overview</h1>
# <div>
#   <h2>Introduction</h2>
#   <p>This mid-century inspired office furniture is part of a beautiful family of products, including filing cabinets, desks, bookcases, meeting tables, and more. The chair is constructed from high-quality materials, including a 5-wheel plastic coated aluminum base and a shell made from cast aluminum with a modified nylon PA6/PA66 coating. The seat is made from HD36 foam, providing optimal comfort and support.</p>
#   <h2>Materials and Construction</h2>
#   <p>The chair's shell has a thickness of 10 mm, ensuring durability and stability. The base finish options include stainless steel, matte black, gloss white, or chrome, allowing for customization to fit any office setting. The chair is also available with or without armrests, providing flexibility for different user preferences.</p>
#   <h2>Product IDs</h2>
#   <p>The following 7-character Product IDs are associated with this product: SWC-100, SWC-110.</p>
# </div>
#
# ...

# %%
from IPython.display import display, HTML

# %%
display(HTML(response))
# Out:
# <h1>Product Overview</h1>
# <div>
#   <h2>Introduction</h2>
#   <p>This mid-century inspired office furniture is part of a beautiful family of products, including filing cabinets, desks, bookcases, meeting tables, and more. The chair is constructed from high-quality materials, including a 5-wheel plastic coated aluminum base and a shell made from cast aluminum with a modified nylon PA6/PA66 coating. The seat is made from HD36 foam, providing optimal comfort and support.</p>
#   <h2>Materials and Construction</h2>
#   <p>The chair's shell has a thickness of 10 mm, ensuring durability and stability. The base finish options include stainless steel, matte black, gloss white, or chrome, allowing for customization to fit any office setting. The chair is also available with or without armrests, providing flexibility for different user preferences.</p>
#   <h2>Product IDs</h2>
#   <p>The following 7-character Product IDs are associated with this product: SWC-100, SWC-110.</p>
# </div>
#
# ...
